# %% [markdown]
# # Pandas tutorial

# %% [markdown]
# Pandas work with DataFrames. We can create DataFrame by converting a .csv file or by converting a Dictionary into DataFrame. Here I have .csv file from stackoverflow.
#
# DataFrame == 2 dimensional structure where data is stored. It is a container of series
# Series == Individual coloumns are called series. More than one series togeter forms a dataframe.

# %%
import pandas as pd
import numpy as np

# %% [raw]
# df.head() == gives first 5 Rows in dataframe. It excepts an integer df.head(10) will give first 10 Rows. Similarly df.tail()
#
# df.shape() == size of dataframe. df.info() -> gives you the heading of columns

# %%
df = pd.read_csv('survey_results_public.csv')

# %% [raw]
# Converting Dictionary to DataFrame
#
# df = pd.DataFrame(Dictionary Name)

# %%
people = dict(first=['Corey', 'Jane', 'John'], 
              last=['Schafer', 'Doe', 'Doe'], 
              email=['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'])
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df2 = pd.DataFrame(people)

# %% [raw]
# df2['emial'] returns series. It returns the column of email

# %%
df2[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df2.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [raw]
# Above we learn how to excess columns. To excess ROWS we have two methods:
#
# df.iloc[] == Returns the ROW by its index
# df.loc[]  == Returns the ROW by its name

# %%
df2.iloc[[0, 1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %% [raw]
# In the above method Rows 0 and 1 is excessed by passing a list and the second argument indicates From this two rows which columns value you would like to excess.

# %%
df2.loc[[0, 1], 'first']
# Out:
# 0    Corey
# 1     Jane
# Name: first, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# ### How to Change Index column

# %% [raw]
# df2.set_index('email', inplace=True)                                  == Changes the index column to the email column
# df2.reset_index(inplace=True)                                         == Changes the index to default
# df = pd.read_csv('survey_results_public.csv', index_col='Respondent') == Changes the index at start
# df2.sort_index()
# df2.sort_index(ascending=False)

# %%
df2.set_index('first', inplace=True)
df2
# Out:
#           last                    email
# first
# Corey  Schafer  CoreyMSchafer@gmail.com
# Jane       Doe        JaneDoe@email.com
# John       Doe        JohnDoe@email.com

# %%
df2.loc[['Corey', 'Jane'], 'last']
# Out:
# first
# Corey    Schafer
# Jane         Doe
# Name: last, dtype: object

# %%
df2.reset_index(inplace=True)

# %% [markdown]
# ### Filtering - Using Conditions to filter Rows and Columns

# %% [raw]
# steps:
# 1. Create a Filter
# 2. Pass it as an argument to the DataFrame loc method in square Brackets

# %%
filt = df2['last'] == 'Doe'
df2.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df2.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df2['last'] == 'Doe') & (df2['first'] == 'John')
df2.loc[~filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
countries = ['United Kingdom', 'Thailand', 'United States', 'India']
filt = df['Country'].isin(countries)
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 9              10                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88854       84539                                                NaN      Yes
# 88859       85642                                                NaN       No
# 88863       85961                                                NaN      Yes
# 88864       86012                                                NaN      Yes
# 88877       88282                                                NaN      Yes
#
# ...

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %% [raw]
# Task : Filter out only those people who knows Python
#
# Here we cannot just put a condition like ['LanguageWorkedWith'] == Python because LanguageWorkedWith is a string.

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ### Modifying Data within DataFrames

# %% [raw]
# -> Rename all columns heading        : df2.columns = ['first_name', 'last_name', 'email']
# -> uppercase all columns heading     : df2.columns = [x.upper() for x in df2.columns]
# -> Replace space with '_'            : df2.columns = df2.columns.str.replace(' ', '_')
# -> Rename specific columns           : df2.rename(columns = {'first_name':'first', 'last_name':'last', inplace=True})
# -> Updating entire row               : df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']
# -> Updating specific column of a Row : df.loc[2, ['last', 'email']] = ['Paavan', 'paavanrshah@gmail.com']
# -> Changing entire column            : df['email'].str.lower()
#
# advanced filtering method
#
# apply ->         apply a function to a series in DataFrame
# applymap ->      applies function to whole DataFrame
# map, replace ->  map method only works for a series. map is used for substituting each value for another value.

# %%
df2['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

df2['email'] = df2['email'].apply(update_email)
df2
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John      Doe        JOHNDOE@EMAIL.COM

# %%
df2['email'] = df2['email'].apply(lambda x: x.lower())
df2
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df2.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df2.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df2.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df2['first'].map({'Corey':'Chris', 'Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %% [raw]
# The valuse that we did not subtituted where converted into NaN values and where gone.
# If we want to keep the other value we use replace method instead of map

# %%
df2['first'].replace({'Corey':'Chris', 'Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %% [markdown]
# ### ADD and REMOVE columns and rows from our DataFrame

# %% [raw]
# adding columns                     -> we can simply create a column and add the values we want
# removing columns                   -> df2.drop(columns=['first', 'last'], inplace=True)
# adding rows & merging DataFrames   -> by using append method

# %%
df2['full_name'] = df2['first'] + ' ' + df2['last']
df2
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe

# %%
df2['email'] = df2['last'] + df2['first'] + '@email.com'
df2
# Out:
#    first     last                   email      full_name
# 0  Corey  Schafer  SchaferCorey@email.com  Corey Schafer
# 1   Jane      Doe       DoeJane@email.com       Jane Doe
# 2   John      Doe       DoeJohn@email.com       John Doe

# %%
df2.drop(columns=['first', 'last'], inplace=True)
df2
# Out:
#                     email      full_name
# 0  SchaferCorey@email.com  Corey Schafer
# 1       DoeJane@email.com       Jane Doe
# 2       DoeJohn@email.com       John Doe

# %%
df2[['first', 'last']] = df2['full_name'].str.split(' ', expand=True)
df2
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe

# %%
df2.append(dict(first="Tony"), ignore_index=True)
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe
# 3                     NaN            NaN   Tony      NaN

# %%
heros = dict(first=['Tony', 'steve'], 
              last=['Stark', 'Rogers'], 
              email=['Ironman@avenger.com', 'Cap@avenger.com'])
hero = pd.DataFrame(heros)
hero
# Out:
#    first    last                email
# 0   Tony   Stark  Ironman@avenger.com
# 1  steve  Rogers      Cap@avenger.com

# %%
df3 = df2.append(hero, ignore_index=True)
df3
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe
# 3     Ironman@avenger.com            NaN   Tony    Stark
# 4         Cap@avenger.com            NaN  steve   Rogers

# %%
df3 = df3.drop(index=3)
df3
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe
# 4         Cap@avenger.com            NaN  steve   Rogers

# %%
filt = df3['last'] == 'Doe'
df3 = df3.drop(index=df3[filt].index)
df3
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 4         Cap@avenger.com            NaN  steve   Rogers

# %%
df3.index = [0, 1]

# %%
df3
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1         Cap@avenger.com            NaN  steve   Rogers

# %%
df2
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe

# %%
df2.sort_values(by='last', ascending=False)
df2.sort_values(by='last')
# Out:
#                     email      full_name  first     last
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer

# %%
df2.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
df2
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe

# %%
df2.sort_index()
# Out:
#                     email      full_name  first     last
# 0  SchaferCorey@email.com  Corey Schafer  Corey  Schafer
# 1       DoeJane@email.com       Jane Doe   Jane      Doe
# 2       DoeJohn@email.com       John Doe   John      Doe

# %% [markdown]
# ### Some Functions

# %% [raw]
# df['ConvertedComp'].nlargest(10) -> shows the 10 largest values in the column
# df['ConvertedComp'].nsmallest(10) -> shows the smallest values in the column
#
# df.nlargest(10, 'ConvertedComp') -> shows the 10 largest values in table format
# df.nlargest(10, 'ConvertedComp')  -> shows 10 smallest values
#
# df['SocialMedia'].value_counts() -> Counts the count of each response
# df['SocialMedia'].counts() -> Counts how many reponses are answered

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 57            58  I am a developer by profession      Yes
# 101          102  I am a developer by profession       No
# 164          166  I am a developer by profession      Yes
# 434          436  I am a developer by profession      Yes
# 450          452  I am a developer by profession      Yes
# 489          491  I am a developer by profession      Yes
# 537          539  I am a developer by profession       No
# 767          770  I am a developer by profession      Yes
# 786          789  I am a developer by profession      Yes
# 1228        1232  I am a developer by profession       No
#
#                                             OpenSourcer  \
# 57                           Once a month or more often
# 101                                               Never
# 164                             Less than once per year
# 434                             Less than once per year
# ...

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %% [markdown]
# ### Grouping and Aggregation

# %% [raw]
# Aggregation : COmbining multiple pieces of data and extracting new information. Mean, Median, Mode are examples of aggregated functions
#
# df['ConvertedComp'].median()
# df.median()
# df.describe()
#
# GroupBy Function involves combination of splitting the object, applying a function and combining those results. It will group the Dataframe according to the parameter passed in groupby object.
#
# We can obtain the desired reults by applying a filter but if we want the same data for multiple countries we will need to apply the filter multiple times.
#
# By using groupby object we did not have to type the code multiple times.

# %%
filt = df['Country'].isin(['India'])
df[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp.groups
# Out:
# {'Afghanistan': Int64Index([  719,  6391,  7056,  7323,  8112, 10697, 12253, 22327, 26189,
#              28470, 28877, 29560, 32971, 37571, 39018, 39754, 42832, 44123,
#              45562, 46807, 48122, 49377, 50172, 50437, 51525, 58082, 58390,
#              59184, 60185, 60559, 61770, 62124, 62723, 73920, 80423, 85185,
#              85293, 85827, 86394, 86551, 88033, 88181, 88340, 88735],
#             dtype='int64'),
#  'Albania': Int64Index([ 1946,  2324,  3771,  6181,  6688,  9190,  9230,  9401, 10257,
#              10480, 10886, 11496, 12208, 13322, 15295, 15461, 15910, 16070,
#              18027, 18193, 18734, 18766, 20030, 20300, 21584, 21638, 24955,
#              24964, 25440, 26040, 27476, 28705, 28995, 29243, 33177, 33385,
#              33999, 35805, 36348, 37134, 38075, 38693, 38869, 40574, 41344,
#              41713, 43601, 43790, 46829, 49389, 49431, 50000, 54739, 55041,
#              55196, 55553, 55572, 55994, 57057, 58394, 59763, 59980, 61881,
# ...

# %%
pasa = country_grp['SocialMedia'].value_counts()
pasa
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
pasa.loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
pasa.loc['India', 'WhatsApp']
# Out:
# 2990

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 7         True
# 9         True
# 14       False
# 49        True
# 64       False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %% [raw]
# Run the Code Below to see ERROR : why we cannot apply .str.contain() directly
#
# country_grp['LanguageWorkedWith'].str.contains('Python').sum()

# %%
country_grp['LanguageWorkedWith']

# %% [raw]
# .str.contains() only works with series and this is a SeriesGroupBy thus it will not work as accepted. We need to access individual series in SeriesGroupBy to make it work.

# %%
Pynum = country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
Pynum
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
Pynum.loc['India']
# Out:
# 3105

# %% [markdown]
# ### Task : What % of people from each country know Python?

# %%
total = country_grp.apply(len)
table = pd.concat([total, Pynum], axis=1, sort=False)
table.columns = ['Total_People', 'Py_People']
table['Py_percent'] = (table['Py_People'] * 100)/table['Total_People']
table.nlargest(10, 'Total_People')
# Out:
#                 Total_People  Py_People  Py_percent
# Country
# United States          20949      10083   48.131176
# India                   9061       3105   34.267741
# Germany                 5866       2451   41.783157
# United Kingdom          5737       2384   41.554820
# Canada                  3395       1558   45.891016
# France                  2391       1054   44.081974
# Brazil                  1948        767   39.373717
# Poland                  1922        751   39.073881
# Australia               1903        790   41.513400
# Netherlands             1852        767   41.414687

# %% [markdown]
# ### Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
persons = dict(first=['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
              last=['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
              email=['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
              age=['33', '55', '63', '36', None, None, 'Missing'])
tab = pd.DataFrame(persons)
tab.replace('NA', np.nan, inplace=True)
tab.replace('Missing', np.nan, inplace=True)
tab
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %% [raw]
# tab.dropna() -> Drops ROWS which has an nan value. It's default arguments are tab.dropna(axis='index', how='any')
#
# tab.dropna(axis='index', how='all')                     -> drops ROWS whose all values are nan
# tab.dropna(axis='index', how='any', subset=['email'])   -> drops ROWS whose email has a nan value
# tab.dropna(axis='columns', how='any')                   -> drops columns which has a nan value
# tab.replace('Missing', np.nan, inplace=True)            -> replaces the coustom missing values with NaN. So, that we can excess                                                            it with the methods associated with NaN
# df.isna()                                               -> Returns Boolean table indicating what value is NaN type
# df.fillna(0) OR df.fillna('MISSING')                    -> Replaces NaN values with the value 0 or MISSING

# %%
tab.dropna(axis='index', how='any')
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
tab.dropna(axis='index', how='all')
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
tab.dropna(axis='index', how='any', subset=['email', 'last'])
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
tab.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
tab.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %% [raw]
# datatypes of this series are object and not int so methods like .mean(), .median() etc cannot be applied without first converting it to int or float type.

# %%
type(np.nan)
# Out:
# float

# %% [raw]
# np.nan has datatype float so it cannot be converted to int but it can be converted to float

# %%
tab['age'] = tab['age'].astype(float)
tab.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
tab['age'].mean()
# Out:
# 46.75

# %% [markdown]
# ### Task : Find the median of column 'YearsCode' in StackOverFlow data

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# ### Reading/Writing Data to Different Sources - Excel, JSON, SQL
#
# This is the Tutorials playlist from where I have learn Pandas.
#
# Last video of this playlist that is part 11 will explain the Reading/Writing Data to Different Sources

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/watch?v=N6hyN6BW6ao&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=12&t=0s" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/watch?v=N6hyN6BW6ao&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=12&t=0s" frameborder="0" allowfullscreen></iframe>
