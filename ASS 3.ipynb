# %%
import pandas as pd

# %%
energy = pd.read_excel('Energy Indicators.xls', usecols='C:F')
energy = energy[17:246]
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy.set_index('Country', inplace=True)

# %%
data = energy.T
data.rename(columns = {"Republic of Korea": "South Korea",
                        "United States of America20": "United States",
                        "United Kingdom of Great Britain and Northern Ireland19": "United Kingdom",
                        "China, Hong Kong Special Administrative Region3": "Hong Kong"}, inplace=True)

# %%
names = list(data.columns)
for i in range(2):
    count = 0
    for item in names: 
        item = str(item)
        l = len(item)
        if item[l-1].isdigit() == True:
            names[count] = item[:l-1]
        count += 1

# %%
count = 0
for item in names: 
    item = str(item)
    if item.find(' (') != -1 :
        names[count] = item[:item.find(' (')]
    count += 1

# %%
data.columns = names 
data.dropna(axis='columns', how='all', inplace=True) 
energy = data.T
energy.index.name = 'Country Name'
energy
# Out:
#                           Energy Supply Energy Supply per Capita % Renewable
# Country Name
# Afghanistan                         321                       10     78.6693
# Albania                             102                       35         100
# Algeria                            1959                       51     0.55101
# American Samoa                      ...                      ...    0.641026
# Andorra                               9                      121     88.6957
# ...                                 ...                      ...         ...
# Viet Nam                           2554                       28     45.3215
# Wallis and Futuna Islands             0                       26           0
# Yemen                               344                       13           0
# Zambia                              400                       26     99.7147
# Zimbabwe                            480                       32     52.5361
#
# [227 rows x 3 columns]

# %%
GDP = pd.read_csv('world_bank.csv')
GDP = GDP[3:270]
GDP.columns = GDP.loc[3]
GDP = GDP[1:270]
years = ['Country Code', 'Indicator Name', 'Indicator Code',
                 1960.0,           1961.0,           1962.0,           1963.0,
                 1964.0,           1965.0,           1966.0,           1967.0,
                 1968.0,           1969.0,           1970.0,           1971.0,
                 1972.0,           1973.0,           1974.0,           1975.0,
                 1976.0,           1977.0,           1978.0,           1979.0,
                 1980.0,           1981.0,           1982.0,           1983.0,
                 1984.0,           1985.0,           1986.0,           1987.0,
                 1988.0,           1989.0,           1990.0,           1991.0,
                 1992.0,           1993.0,           1994.0,           1995.0,
                 1996.0,           1997.0,           1998.0,           1999.0,
                 2000.0,           2001.0,           2002.0,           2003.0,
                 2004.0,           2005.0,]
GDP.drop(columns = years, inplace=True)
GDP.set_index('Country Name', inplace=True)
GDP.columns = [int(x) for x in GDP.columns]

# %%
g = GDP.T
g.rename(columns = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"}, inplace=True) 
GDP = g.T
GDP
# Out:
#                           2006          2007          2008          2009  \
# Country Name
# Aruba                      NaN           NaN           NaN           NaN
# Andorra           4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan       1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola            5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania           9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ...                        ...           ...           ...           ...
# Yemen, Rep.       2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# South Africa      3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# Zambia            1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# Zimbabwe          1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#                           2010          2011          2012          2013  \
# ...

# %%
raw = pd.read_excel('scimagojr-3.xlsx')
raw.set_index('Country', inplace=True)
ScimEn = raw.nsmallest(15, 'Rank')
ScimEn.index.name = 'Country Name'
ScimEn
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
df = pd.merge(ScimEn, energy, how='left', left_on='Country Name', right_on='Country Name')
answer = pd.merge(df, GDP, how='left', left_on='Country Name', right_on='Country Name')
answer
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
print(energy.shape)
print(GDP.shape)
print(raw.shape)
print(answer.shape)
energy
# Out:
# (227, 3)
# (264, 10)
# (191, 7)
# (15, 20)
#                           Energy Supply Energy Supply per Capita % Renewable
# Country Name
# Afghanistan                         321                       10     78.6693
# Albania                             102                       35         100
# Algeria                            1959                       51     0.55101
# American Samoa                      ...                      ...    0.641026
# Andorra                               9                      121     88.6957
# ...                                 ...                      ...         ...
# Viet Nam                           2554                       28     45.3215
# Wallis and Futuna Islands             0                       26           0
# Yemen                               344                       13           0
# Zambia                              400                       26     99.7147
# ...

# %%
answer_two = (energy.shape[0] + GDP.shape[0] + raw.shape[0]) - answer.shape[0]

# %%
answer_two
# Out:
# 667

# %% [markdown]
# ### Question 3 (6.6%)
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
#
# *This function should return a Series named `avgGDP` with 15 countries and their average GDP sorted in descending order.*

# %%
ans_two = answer[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]
ans_two.fillna(0)
ans_two.head()
# Out:
#                             2006          2007          2008          2009  \
# Country Name
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# United States       1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# United Kingdom      2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
#
#                             2010          2011          2012          2013  \
# Country Name
# China               6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# United States       1.496437e+13  1.520402e+13  1.554216e+13  1.577367e+13
# Japan               5.498718e+12  5.473738e+12  5.569102e+12  5.644659e+12
# United Kingdom      2.403504e+12  2.450911e+12  2.479809e+12  2.533370e+12
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
#
# ...

# %%
copy = ans_two.copy()
copy['AvgGDP'] = (copy.sum(axis=1)/10)

# %%
copy['AvgGDP'].nlargest(15)
# Out:
# Country Name
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  3.997402e+11
# Name: AvgGDP, dtype: float64

# %% [markdown]
# ### Question 4 (6.6%)
# By how much had the GDP changed over the 10 year span for the country with the 6th largest average GDP?
#
# *This function should return a single number.*

# %%
ans_four = copy.nlargest(6, 'AvgGDP')
ans_four
# Out:
#                         2006          2007          2008          2009  \
# Country Name
# United States   1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# China           3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# Japan           5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# Germany         3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# France          2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# United Kingdom  2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
#
#                         2010          2011          2012          2013  \
# Country Name
# United States   1.496437e+13  1.520402e+13  1.554216e+13  1.577367e+13
# China           6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# Japan           5.498718e+12  5.473738e+12  5.569102e+12  5.644659e+12
# Germany         3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# France          2.646995e+12  2.702032e+12  2.706968e+12  2.722567e+12
# ...

# %%
change = ans_four.iloc[5]

# %%
gdpchange = change[2015] - change[2006]
gdpchange
# Out:
# 246702696075.3999

# %% [markdown]
# ### Question 5 (6.6%)
# What is the mean `Energy Supply per Capita`?
#
# *This function should return a single number.*

# %%
answer.index.size
# Out:
# 15

# %%
answer['Energy Supply per Capita'].sum() / answer.index.size
# Out:
# 157.6

# %% [markdown]
# ### Question 6 (6.6%)
# What country has the maximum % Renewable and what is the percentage?
#
# *This function should return a tuple with the name of the country and the percentage.*

# %%
filt = answer['% Renewable'] == answer['% Renewable'].max()
p = answer[filt]['% Renewable']

# %%
p
# Out:
# Country Name
# Brazil    69.648
# Name: % Renewable, dtype: object

# %%
c = list(p.index)
for item in c:
    print(item)
# Out:
# Brazil

# %% [markdown]
# ### Question 7 (6.6%)
# Create a new column that is the ratio of Self-Citations to Total Citations.
# What is the maximum value for this new column, and what country has the highest ratio?
#
# *This function should return a tuple with the name of the country and the ratio.*

# %%
raw
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Guyana               187          1                  1          0
# Christmas Island     188          1                  1          0
# Reunion              189          1                  1          2
# Saint Lucia          190          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# ...

# %%
answer.columns
# Out:
# Index([                    'Rank',                'Documents',
#               'Citable documents',                'Citations',
#                  'Self-citations',   'Citations per document',
#                         'H index',            'Energy Supply',
#        'Energy Supply per Capita',              '% Renewable',
#                              2006,                       2007,
#                              2008,                       2009,
#                              2010,                       2011,
#                              2012,                       2013,
#                              2014,                       2015],
#       dtype='object')

# %%
answer['ratio'] = answer['Self-citations']/answer['Citations']

# %%
answer
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
max_ratio = answer['ratio'].nlargest(1)

# %%
list(max_ratio)
list(max_ratio.index)
# Out:
# ['China']

# %%
a = zip(list(max_ratio.index), list(max_ratio))
a = list(a)
a = tuple(a)

# %%
b = a[0]
b
# Out:
# ('China', 0.6893126179389422)

# %% [markdown]
# ### Question 8 (6.6%)
#
# Create a column that estimates the population using Energy Supply and Energy Supply per capita.
# What is the third most populous country according to this estimate?
#
# *This function should return a single string value.*

# %%
answer
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
answer['pop'] = answer['Energy Supply']/answer['Energy Supply per Capita']

# %%
population = list()
for item in answer['pop']:
    item = int(item)
    population.append(item)

# %%
answer['pop'] = population 
answer.nlargest(3, 'pop')
# Out:
#                Rank  Documents  Citable documents  Citations  Self-citations  \
# Country Name
# China             1     127050             126767     597237          411683
# India             8      15005              14841     128763           37209
# United States     2      96661              94747     792274          265436
#
#                Citations per document  H index Energy Supply  \
# Country Name
# China                            4.70      138        127191
# India                            8.58      115         33195
# United States                    8.20      230         90838
#
#               Energy Supply per Capita % Renewable  ...          2008  \
# Country Name                                        ...
# China                               93     19.7549  ...  4.997775e+12
# India                               26     14.9691  ...  1.428361e+12
# United States                      286      11.571  ...  1.501149e+13
#
# ...

# %%
filt = answer['pop'] == answer['pop'].nlargest(3)[-1]
for item in list(answer[filt].index):
    print(item)
# Out:
# United States

# %% [markdown]
# ### Question 9 (6.6%)
# Create a column that estimates the number of citable documents per person.
# What is the correlation between the number of citable documents per capita and the energy supply per capita? Use the `.corr()` method, (Pearson's correlation).
#
# *This function should return a single number.*
#
# *(Optional: Use the built-in function `plot9()` to visualize the relationship between Energy Supply per Capita vs. Citable docs per Capita)*

# %%
ans_nine = answer.copy()
ans_nine
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
ans_nine['citation per person'] = ans_nine['Citable documents']/ans_nine['pop']

# %%
ans_nine
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
cos = ans_nine[['citation per person','Energy Supply per Capita']].copy()
cos['Energy Supply per Capita'] = cos['Energy Supply per Capita'].astype(float)

# %%
cos.corr().iloc[0,1]
# Out:
# 0.7918111781394221

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(cos['Energy Supply per Capita'], cos['citation per person'])

# %%
import numpy as np

data = np.array(['g','e','e','k','s'])
 
ser = pd.Series(data)
ser
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %% [markdown]
# ### Question 11 (6.6%)
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```python
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
#
# *This function should return a DataFrame with index named Continent `['Asia', 'Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`*

# %%
answer
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country Name
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
import numpy as np
import pandas as pd
Top15 = answer
ContinentDict  = {'China':'Asia',
                  'United States':'North America', 
                  'Japan':'Asia',
                  'United Kingdom':'Europe',
                  'Russian Federation':'Europe',
                  'Canada':'North America',
                    'Germany':'Europe', 
                    'India':'Asia',
                    'France':'Europe', 
                    'South Korea':'Asia', 
                    'Italy':'Europe', 
                    'Spain':'Europe', 
                    'Iran':'Asia',
                    'Australia':'Australia', 
                    'Brazil':'South America'}
Top15['Continent'] = Top15.index.map(ContinentDict)
Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
result = Top15.copy()
res = result[['Continent', 'PopEst']].copy()
res['PopEst'] = result.PopEst.astype(float)
conty = res.groupby(['Continent'])

# %%
conty['PopEst'].agg(['size', 'sum', 'mean', 'std'])
# Out:
#                size          sum        mean         std
# Continent
# Asia              5  2898.666387  579.733277  679.097888
# Australia         1    23.316017   23.316017         NaN
# Europe            6   457.929667   76.321611   34.647667
# North America     2   352.855249  176.427625  199.669645
# South America     1   205.915254  205.915254         NaN

# %% [markdown]
# ### Question 10 (6.6%)
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# *This function should return a series named `HighRenew` whose index is the country name sorted in ascending order of rank.*

# %%
result['% Renewable'].mean()
# Out:
# 22.824394266666665

# %%
result['HighRenew'] = 0
if (result['% Renewable'] > result['% Renewable'].mean()).bool():
    result['HighRenew'] = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-cc69ae06fe31> in <module>
#       1 result['HighRenew'] = 0
# ----> 2 if (result['% Renewable'] > result['% Renewable'].mean()).bool():
#       3     result['HighRenew'] = 1
#
# F:\Anaconda\lib\site-packages\pandas\core\generic.py in bool(self)
#    1505             )
#    1506
# -> 1507         self.__nonzero__()
#    1508
#    1509     def __abs__(self: FrameOrSeries) -> FrameOrSeries:
#
# F:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ...

# %%
count = result['% Renewable'].mean()
h = list()
for item in result['% Renewable']:
    if item > count:
        h.append(True)
    else:
        h.append(False)

# %%
h
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True]

# %%
result['HighRenew'] = h

# %%
result['HighRenew']
# Out:
# Country Name
# China                 False
# United States         False
# Japan                 False
# United Kingdom        False
# Russian Federation    False
# Canada                 True
# Germany               False
# India                 False
# France                False
# South Korea           False
# Italy                  True
# Spain                  True
# Iran                  False
# Australia             False
# Brazil                 True
# Name: HighRenew, dtype: bool

# %% [markdown]
# ### Question 12 (6.6%)
# Cut % Renewable into 5 bins. Group Top15 by the Continent, as well as these new % Renewable bins. How many countries are in each of these groups?
#
# *This function should return a __Series__ with a MultiIndex of `Continent`, then the bins for `% Renewable`. Do not include groups with no countries.*
